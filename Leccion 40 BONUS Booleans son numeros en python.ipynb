# %%
# En Python los valores True o False son términos que representan el 1 y 0.
True + 19
# Out:
# 20

# %%
True - False + True * 3
# Out:
# 4

# %%
5/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-47-05522ed6f6a6> in <module>()
# ----> 1 5/False
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Este comportamiento se debe a que un boolean es un tipo de entero que a su ves es un tipo objeto y está definido en el Method Resolution Order o MRO

# %%
type(True)
# Out:
# bool

# %%
bool.__mro__
# Out:
# (bool, int, object)
