# %% [markdown]
# # Leccion 56 - Pairwise differences with diff()

# %%
import pandas as pd
import numpy as np

alcohol = pd.read_csv('https://andybek.com/pandas-drinks', usecols=['country', 'wine_servings'], index_col=['country'], squeeze=True)

# %%
# diff() regresa una Serie con la diferencia del elemento menos su antecesor por default
alcohol.diff()
# Out:
# country
# Afghanistan      NaN
# Albania          NaN
# Algeria        -40.0
# Andorra        298.0
# Angola        -267.0
#                ...
# Venezuela       -8.0
# Vietnam         -2.0
# Yemen            NaN
# Zambia           NaN
# Zimbabwe         0.0
# Name: wine_servings, Length: 193, dtype: float64

# %%
# Podemos cambiar el antecesor con period en este sería elemento3 - elemento 1, elemento 4 - elemento 2, ...
alcohol.diff(periods = 2)
# Out:
# country
# Afghanistan      NaN
# Albania          NaN
# Algeria          NaN
# Andorra        258.0
# Angola          31.0
#                ...
# Venezuela       -5.0
# Vietnam        -10.0
# Yemen            NaN
# Zambia           3.0
# Zimbabwe         NaN
# Name: wine_servings, Length: 193, dtype: float64

# %%
# Podemos hacer un periodo negativo lo cual cambia el orden de los operandos, en este caso E1 - E2, E2- E3
alcohol.diff(periods = -1)
# Out:
# country
# Afghanistan      NaN
# Albania         40.0
# Algeria       -298.0
# Andorra        267.0
# Angola           0.0
#                ...
# Venezuela        2.0
# Vietnam          NaN
# Yemen            NaN
# Zambia           0.0
# Zimbabwe         NaN
# Name: wine_servings, Length: 193, dtype: float64
